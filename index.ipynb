# %% [markdown]
# ## Introduction
#
# In this lab, you'll get to do your first real data science project! You'll use Jupyter Notebook to import pre-written libraries, you'll import data into your notebook from a Comma Seperated Values file (a .csv file) and you'll even get to create some plots!
#
# Don't worry if it feels like a lot or you get confused on this lab. Our goal here is just to give you a taste of what you'll be able to do as a data scientist, and after this lab, we'll go back and re-introduce all of the concepts that we skimmed over this time through, so by the end of the section you should have a much stronger understanding of this - even if you have no previous experience of programming.
#
# Don't worry about running tests for this lab. Just take your time to explore the data and the code.

# %% [markdown]
# ## Objectives
# You will be able to:
# * Code along (following detailed instructions) to import a csv file and then plot the data

# %% [markdown]
# ## Jupyter Notebook and Running Cells
#
# **Welcome to programming!**
# Juptyer Notebooks (historically called IPythonNotebooks) will be our primary tool when conducting data science. The first thing to know with this is that each cell block [of code] can be run be pressing **shift+enter**. Try running the below code block:

# %%
print('This is code being run.')
# Out:
# This is code being run.

# %% [markdown]
# ## Importing Packages
# The next thing we're going to do is load in some python packages that will be part of our toolbox for manipulating and analyzing data. The standard python package for working with data tables is called **pandas**. Below, we import this under the **alias** pd, which is the industry standard. This will give us a shorthand way to access special functions and methods within the package without having to type the longer name pandas.
#
# * Again, press **shift+enter** to run the code below

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Jupyter Notebook Cell Types
#
# You might have started to notice that the code blocks have little notes that say **In [ ]:** before you run them, and then are filled with a number after you run them. This is important, as it tells you what order cell blocks were run. (Which can sometimes affect how a program runs.)
#
# You may also notice that other cell blocks, such as this one, do not have the **In [ ]:** label as with the code blocks. This is because this cell block is formatted as **Markdown** rather then code. You can see (and change) what type of cell is by clicking the dropdown menu at the top:
# <img src="Jupyter_Notebook_Cell_Type_Dropdown.png" width=600>

# %% [markdown]
# # Command Versus Edit Mode
#
# You should also start to notice that when you are in a cell writing code (or notes), the cell is highlighted in **green** meaning you are in **edit mode**.
#
# Alternatively, if you **press esc**, the cursor will be in **blue** inidicating that you are in **command mode**.
#
# ### Edit Mode
# Edit mode is the standard mode for editing cells, whether its writing code or notes.
# To enter edit mode from command mode simply hit enter, or double click on a cell.
#
# ### Command Mode
# In command mode, you can delete cells, add cells, copy cells, paste cells, change cell types, and more. You can also do these tasks in a more cumbersome (and time consuming) manner by using the various headers in the menu bar at top.
# <img src="Jupyter_Menu.png" width=600>
# You can also see a full list of shortcuts available in command and edit mode under the help menu.
#
# <img src="Jupyter_Help_Menu.png" width=600>

# %% [markdown]
# # Running Bash Commands
#
# We can also run bash commands just as we did before from the terminal directly within iPython notebooks!
#  (Note: bash commands cannot be mixed with python and must be in their own cell block.)
#
# Try it out!

# %%
pwd
# Out:
# '/Users/rpothann/development/flatiron/module01/section01/dsc-1-01-08-your-first-data-science-project-lab-online-ds-ft-112618'

# %%
ls
# Out:
# CONTRIBUTING.md
# Jupyter_Help_Menu.png
# Jupyter_Menu.png
# Jupyter_Notebook_Cell_Type_Dropdown.png
# LICENSE.md
# README.md
# docstring.png
# docstring_preview.png
# index.ipynb
# index_files/
# lego_sets.csv*
# pd_methods.png
# pd_read_methods.png
# python_built_in_functions.png
# string-slicing.png

# %% [markdown]
# ## Loading a DataFrame
# The primary datatype within the pandas package is called a dataframe and is similar to a spreadsheet in excel. Here's a brief example of loading a csv file from your hard drive:

# %%
df = pd.read_csv('lego_sets.csv') #Loads the dataframe in
print(len(df)) #Prints the length of the dataframe
df.head() #Uses a built in method common to all Pandas Dataframes
# Out:
# 12261
#    ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0  6-12       29.99          2.0        277.0               4.0
# 1  6-12       19.99          2.0        168.0               4.0
# 2  6-12       12.99         11.0         74.0               4.3
# 3   12+       99.99         23.0       1032.0               3.6
# 4   12+       79.99         14.0        744.0               3.2
#
#                                            prod_desc  prod_id  \
# 0  Catapult into action and take back the eggs fr...  75823.0
# 1  Launch a flying attack and rescue the eggs fro...  75822.0
# 2  Chase the piggy with lightning-fast Chuck and ...  75821.0
# 3  Explore the architecture of the United States ...  21030.0
# 4  Recreate the Solomon R. Guggenheim Museum® wit...  21035.0
#
#                                       prod_long_desc review_difficulty  \
# 0  Use the staircase catapult to launch Red into ...           Average
# 1  Pilot Pig has taken off from Bird Island with ...              Easy
# 2  Pitch speedy bird Chuck against the Piggy Car....              Easy
# 3  Discover the architectural secrets of the icon...           Average
# 4  Discover the architectural secrets of Frank Ll...       Challenging
#
#                          set_name  star_rating    theme_name  val_star_rating  \
# 0           Bird Island Egg Heist          4.5  Angry Birds™              4.0
# 1              Piggy Plane Attack          5.0  Angry Birds™              4.0
# 2                Piggy Car Escape          4.3  Angry Birds™              4.1
# 3  United States Capitol Building          4.6  Architecture              4.3
# 4   Solomon R. Guggenheim Museum®          4.6  Architecture              4.1
#
#   country
# 0      US
# 1      US
# 2      US
# 3      US
# 4      US

# %% [markdown]
# # Python Comments
#
# Note the green text following the **#**.
# Anything following a **#** in python is a comment and will not actually execute.
# This is a useful feature for annotating your code with notes for yourself and other later so that your code is easy to read.

# %% [markdown]
# # Accessing Methods from Packages and Objects
#
# A little more theory and context:
#
# When we loaded in packages on our first cell block (import pandas as pd), we loaded code into memory. That code included functions, variables and other objects. Collectively, all of these items is loaded under the package name or alias.
#
# We demonstrated this when we used the **pd.read_csv()** method above.
#
# This also demonstrates the **dot notation** in python, which is how we access built in methods or attriubtes of a given object. Similar to what we saw with bash in the command line, we can also use **tab completion** to preview methods available in packages or other objects.
#
# ### Try this out yourself
#
# * In the cell below, navigate your cursor to the right of **pd.**
# * Press tab to see a list of available methods/attributes
#
# <img src="pd_methods.png" width=600>

# %%
pd.read_csv('lego_sets.csv')
# Out:
#        ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0      6-12     29.9900          2.0        277.0               4.0
# 1      6-12     19.9900          2.0        168.0               4.0
# 2      6-12     12.9900         11.0         74.0               4.3
# 3       12+     99.9900         23.0       1032.0               3.6
# 4       12+     79.9900         14.0        744.0               3.2
# 5       12+     59.9900          7.0        597.0               3.7
# 6       12+     59.9900         37.0        598.0               3.7
# 7       12+     49.9900         24.0        780.0               4.4
# 8       12+     39.9900         23.0        468.0               3.6
# 9       12+     39.9900         11.0        444.0               3.6
# 10      12+     39.9900         14.0        386.0               4.1
# 11      12+     34.9900         53.0        321.0               3.2
# 12      12+     29.9900          7.0        361.0               4.2
# 13     7-12    159.9900         63.0        847.0               3.8
# 14      10+     29.9900         13.0        708.0               4.7
# 15      10+     19.9900          1.0        234.0               3.0
# 16      10+     19.9900          1.0        160.0               5.0
# 17      10+      9.9900          1.0        149.0               2.0
# 18      10+      9.9900          1.0        141.0               2.0
# 19      10+      9.9900          3.0        101.0               4.0
# 20      10+      9.9900          2.0        105.0               3.0
# 21      10+      9.9900          1.0        113.0               5.0
# 22      10+      9.9900          1.0        136.0               NaN
# 23      10+      9.9900          2.0         91.0               3.0
# 24      10+      9.9900          7.0        140.0               3.2
# 25      10+      9.9900          5.0        143.0               4.6
# 26      10+      9.9900          3.0        122.0               2.7
# 27      10+      9.9900          5.0        130.0               4.3
# 28      10+      9.9900          3.0        119.0               4.5
# 29      10+      9.9900          1.0        135.0               1.0
# ...     ...         ...          ...          ...               ...
# 12231  7-14     48.7878          5.0        267.0               3.6
# 12232  7-14     48.7878         12.0        293.0               4.9
# 12233  8-14     42.6878         24.0        305.0               4.5
# 12234  7-14     42.6878         18.0        254.0               4.2
# 12235  7-14     30.4878          2.0        198.0               4.0
# 12236  7-14     30.4878          8.0        204.0               4.1
# 12237  7-14     30.4878         19.0        201.0               4.1
# 12238  6-12     18.2878          7.0        141.0               4.0
# 12239  6-12     18.2878         18.0        124.0               4.5
# 12240    5+      4.8678         13.0          8.0               4.3
# 12241  8-14    103.6878          9.0        643.0               4.4
# 12242   16+    365.9878         88.0       4867.0               4.8
# 12243  9-14    225.6878         52.0       2295.0               4.7
# 12244  9-14    134.1878         15.0       1403.0               4.5
# 12245  9-14    103.6878          9.0        830.0               4.6
# 12246  9-14    103.6878         11.0       1202.0               4.7
# 12247  9-14     97.5878          6.0        914.0               4.8
# 12248  9-14     97.5878         19.0        944.0               3.6
# 12249  9-14     82.9478          8.0        876.0               4.7
# 12250  8-14     73.1878          8.0        747.0               4.3
# 12251  8-14     60.9878          7.0        521.0               4.7
# 12252  8-14     60.9878         29.0        544.0               4.6
# 12253  8-14     48.7878         21.0        494.0               4.6
# 12254  7-14     36.5878         10.0        312.0               3.5
# 12255  8-14     36.5878          8.0        341.0               4.2
# 12256  7-14     36.5878          6.0        341.0               4.4
# 12257  7-14     24.3878          8.0        217.0               4.1
# 12258  7-14     24.3878         18.0        233.0               4.6
# 12259  6-14     12.1878          1.0         48.0               5.0
# 12260  6-14     12.1878         11.0        109.0               4.5
#
#                                                prod_desc  prod_id  \
# 0      Catapult into action and take back the eggs fr...  75823.0
# 1      Launch a flying attack and rescue the eggs fro...  75822.0
# 2      Chase the piggy with lightning-fast Chuck and ...  75821.0
# 3      Explore the architecture of the United States ...  21030.0
# 4      Recreate the Solomon R. Guggenheim Museum® wit...  21035.0
# 5      Celebrate Shanghai with this LEGO® Architectur...  21039.0
# 6      Celebrate New York City with this LEGO® Archit...  21028.0
# 7      Recreate Buckingham Palace with LEGO® Architec...  21029.0
# 8      Celebrate London with this LEGO® Architecture ...  21034.0
# 9      Celebrate Chicago with this LEGO® Architecture...  21033.0
# You can also start typing to subset the list of available commands:
# <img src="pd_read_methods.png" width=600>

# %% [markdown]
# # Pulling up Docstrings
#
# Even better, you can even see how a method works by pulling up its **docstring**!
# You can do this by writing **?** after the method and running the cell.
#
# <img src="docstring.png" width=500>
#
#
# Try it out!

# %% [markdown]
# Alternatively, you can pull up a preview of the docstring by pressing **shift+tab within the parentheses of a method**
# <img src="docstring_preview.png" width=500>

# %%
pd.Expr?

# %%
pd.read_csv('lego_sets.csv')#Move your cursor inside the parentheses and press shift+tab
# Out:
#        ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0      6-12     29.9900          2.0        277.0               4.0
# 1      6-12     19.9900          2.0        168.0               4.0
# 2      6-12     12.9900         11.0         74.0               4.3
# 3       12+     99.9900         23.0       1032.0               3.6
# 4       12+     79.9900         14.0        744.0               3.2
# 5       12+     59.9900          7.0        597.0               3.7
# 6       12+     59.9900         37.0        598.0               3.7
# 7       12+     49.9900         24.0        780.0               4.4
# 8       12+     39.9900         23.0        468.0               3.6
# 9       12+     39.9900         11.0        444.0               3.6
# 10      12+     39.9900         14.0        386.0               4.1
# 11      12+     34.9900         53.0        321.0               3.2
# 12      12+     29.9900          7.0        361.0               4.2
# 13     7-12    159.9900         63.0        847.0               3.8
# 14      10+     29.9900         13.0        708.0               4.7
# 15      10+     19.9900          1.0        234.0               3.0
# 16      10+     19.9900          1.0        160.0               5.0
# 17      10+      9.9900          1.0        149.0               2.0
# 18      10+      9.9900          1.0        141.0               2.0
# 19      10+      9.9900          3.0        101.0               4.0
# 20      10+      9.9900          2.0        105.0               3.0
# 21      10+      9.9900          1.0        113.0               5.0
# 22      10+      9.9900          1.0        136.0               NaN
# 23      10+      9.9900          2.0         91.0               3.0
# 24      10+      9.9900          7.0        140.0               3.2
# 25      10+      9.9900          5.0        143.0               4.6
# 26      10+      9.9900          3.0        122.0               2.7
# 27      10+      9.9900          5.0        130.0               4.3
# 28      10+      9.9900          3.0        119.0               4.5
# 29      10+      9.9900          1.0        135.0               1.0
# ...     ...         ...          ...          ...               ...
# 12231  7-14     48.7878          5.0        267.0               3.6
# 12232  7-14     48.7878         12.0        293.0               4.9
# 12233  8-14     42.6878         24.0        305.0               4.5
# 12234  7-14     42.6878         18.0        254.0               4.2
# 12235  7-14     30.4878          2.0        198.0               4.0
# 12236  7-14     30.4878          8.0        204.0               4.1
# 12237  7-14     30.4878         19.0        201.0               4.1
# 12238  6-12     18.2878          7.0        141.0               4.0
# 12239  6-12     18.2878         18.0        124.0               4.5
# 12240    5+      4.8678         13.0          8.0               4.3
# 12241  8-14    103.6878          9.0        643.0               4.4
# 12242   16+    365.9878         88.0       4867.0               4.8
# 12243  9-14    225.6878         52.0       2295.0               4.7
# 12244  9-14    134.1878         15.0       1403.0               4.5
# 12245  9-14    103.6878          9.0        830.0               4.6
# 12246  9-14    103.6878         11.0       1202.0               4.7
# 12247  9-14     97.5878          6.0        914.0               4.8
# 12248  9-14     97.5878         19.0        944.0               3.6
# 12249  9-14     82.9478          8.0        876.0               4.7
# 12250  8-14     73.1878          8.0        747.0               4.3
# 12251  8-14     60.9878          7.0        521.0               4.7
# 12252  8-14     60.9878         29.0        544.0               4.6
# 12253  8-14     48.7878         21.0        494.0               4.6
# 12254  7-14     36.5878         10.0        312.0               3.5
# 12255  8-14     36.5878          8.0        341.0               4.2
# 12256  7-14     36.5878          6.0        341.0               4.4
# 12257  7-14     24.3878          8.0        217.0               4.1
# 12258  7-14     24.3878         18.0        233.0               4.6
# 12259  6-14     12.1878          1.0         48.0               5.0
# 12260  6-14     12.1878         11.0        109.0               4.5
#
#                                                prod_desc  prod_id  \
# 0      Catapult into action and take back the eggs fr...  75823.0
# 1      Launch a flying attack and rescue the eggs fro...  75822.0
# 2      Chase the piggy with lightning-fast Chuck and ...  75821.0
# 3      Explore the architecture of the United States ...  21030.0
# 4      Recreate the Solomon R. Guggenheim Museum® wit...  21035.0
# 5      Celebrate Shanghai with this LEGO® Architectur...  21039.0
# 6      Celebrate New York City with this LEGO® Archit...  21028.0
# 7      Recreate Buckingham Palace with LEGO® Architec...  21029.0
# 8      Celebrate London with this LEGO® Architecture ...  21034.0
# 9      Celebrate Chicago with this LEGO® Architecture...  21033.0
# 10       Experience the grandeur of the Arc de Triomphe!  21036.0
# 11     Build your own LEGO® interpretation of the ico...  21019.0
# 12     Celebrate Sydney with this LEGO® Architecture ...  21032.0
# 13                   Bring your LEGO® creations to life!  17101.0
# 14         Build a LEGO® BrickHeadz version of yourself!  41597.0
# 15     Train a raptor with LEGO® BrickHeadz™ Owen and...  41614.0
# 16     Join Mr. Incredible and Frozone for LEGO® Bric...  41613.0
# 17     Growl like a Wookiee with a LEGO® BrickHeadz™ ...  41609.0
# 18     Be a rogue with a LEGO® BrickHeadz™ constructi...  41608.0
# 19     Save the universe with LEGO® BrickHeadz Iron M...  41604.0
# 20     Feel the power of Infinity with LEGO® BrickHea...  41605.0
# 21     Be a legendary outlaw with LEGO® BrickHeadz St...  41606.0
# 22     Master the skills of a green-skinned assassin ...  41607.0
# 23     Join the Resistance with a LEGO® BrickHeadz co...  41485.0
# 24     Say “I love you” with a LEGO® BrickHeadz™ Vale...  40270.0
# 25       Stand tall with LEGO® BrickHeadz Wonder Woman™!  41599.0
# 26     Live life in the fast lane with LEGO® BrickHea...  41598.0
# 27     Summon the dark side with a LEGO® BrickHeadz c...  41603.0
# 28     Feel the Force with a LEGO® BrickHeadz constru...  41602.0
# 29               Dive in with LEGO® BrickHeadz Aquaman™!  41600.0
# ...                                                  ...      ...
# 12231               Party on with Superman™ and friends!  70919.0
# 12232              Join Batman™ in a comical food fight!  70920.0
# 12233  Put the heat on The Penguin™ Arctic Roller wit...  70911.0
# 12234  Battle with Batman™ against The Riddler™ and h...  70903.0
# 12235  Bring down Captain Boomerang™ with Batman’s Ba...  70918.0
# 12236  Help Batman™ to stop Scarecrow™ delivering a s...  70910.0
# 12237  Protect the power plant from Mr. Freeze’s ice ...  70901.0
# 12238  Power into the sky to stop Scarecrow’s fear ga...  70913.0
# 12239             Help Batman™ stop The Joker™ escaping!  70900.0
# 12240  Discover new heroes and villains in LEGO® Mini...  71020.0
# 12235                      The Bat-Dune Buggy          4.5
# 12236             Scarecrow™ Special Delivery          4.4
# 12237                  Mr. Freeze™ Ice Attack          4.6
# 12238             Scarecrow™ Fearful Face-off          4.1
# 12239               The Joker™ Balloon Escape          4.7
# 12240         THE LEGO® BATMAN MOVIE Series 2          4.8
# 12241                   The Bat-Space Shuttle          4.8
# 12242                           NINJAGO® City          4.9
# 12243                        Destiny's Bounty          4.9
# 12244  Temple of The Ultimate Ultimate Weapon          4.8
# 12245           garmadon, Garmadon, GARMADON!          4.9
# 12246                              Quake Mech          4.5
# 12247                                Ice Tank          4.8
# 12248                               Fire Mech          4.2
# 12249                           Lightning Jet          5.0
# 12250                         Garma Mecha Man          4.5
# 12251                 Garmadon's Volcano Lair          4.3
# 12252                 Green Ninja Mech Dragon          4.7
# 12253                           Water Strider          4.5
# 12254                            Master Falls          4.0
# 12255                        Flying Jelly Sub          4.6
# 12256                        Manta Ray Bomber          4.3
# 12257                          Piranha Attack          3.6
# 12258                     NINJAGO® City Chase          4.6
# 12259                Lloyd - Spinjitzu Master          5.0
# 12260                      Spinjitzu Training          4.7
#
#                       theme_name  val_star_rating country
# 0                   Angry Birds™              4.0      US
# 1                   Angry Birds™              4.0      US
# 2                   Angry Birds™              4.1      US
# 3                   Architecture              4.3      US
# 4                   Architecture              4.1      US
# 5                   Architecture              4.4      US
# 6                   Architecture              4.1      US
# 7                   Architecture              4.3      US
# 8                   Architecture              4.1      US
# 9                   Architecture              4.5      US
# 10                  Architecture              3.6      US
# 11                  Architecture              4.4      US
# 12                  Architecture              4.2      US
# 13                         BOOST              3.5      US
# 14                    BrickHeadz              4.8      US
# 15                    BrickHeadz              5.0      US
# 16                    BrickHeadz              5.0      US
# 17                    BrickHeadz              4.0      US
# 18                    BrickHeadz              4.0      US
# 19                    BrickHeadz              4.5      US
# 20                    BrickHeadz              5.0      US
# 21                    BrickHeadz              5.0      US
# 22                    BrickHeadz              NaN      US
# 23                    BrickHeadz              4.0      US
# 24                    BrickHeadz              4.7      US
# 25                    BrickHeadz              5.0      US
# 26                    BrickHeadz              3.0      US
# 27                    BrickHeadz              4.8      US
# 28                    BrickHeadz              4.5      US
# 29                    BrickHeadz              3.0      US
# ...                          ...              ...     ...
# 12231     THE LEGO® BATMAN MOVIE              3.4      PT
# 12232     THE LEGO® BATMAN MOVIE              4.6      PT
# 12233     THE LEGO® BATMAN MOVIE              4.4      PT
# 12234     THE LEGO® BATMAN MOVIE              4.4      PT
# 12235     THE LEGO® BATMAN MOVIE              4.0      PT
# 12236     THE LEGO® BATMAN MOVIE              4.1      PT
# 12237     THE LEGO® BATMAN MOVIE              4.4      PT
# 12238     THE LEGO® BATMAN MOVIE              4.4      PT
# 12239     THE LEGO® BATMAN MOVIE              4.6      PT
# 12240                Minifigures              4.0      PT
# 12241     THE LEGO® BATMAN MOVIE              3.5      PT
# 12242  THE LEGO® NINJAGO® MOVIE™              4.8      PT
# 12243  THE LEGO® NINJAGO® MOVIE™              4.8      PT
# 12244  THE LEGO® NINJAGO® MOVIE™              4.8      PT
# 12245  THE LEGO® NINJAGO® MOVIE™              4.8      PT
# 12246  THE LEGO® NINJAGO® MOVIE™              4.4      PT
# 12247  THE LEGO® NINJAGO® MOVIE™              4.7      PT
# 12248  THE LEGO® NINJAGO® MOVIE™              4.6      PT
# 12249  THE LEGO® NINJAGO® MOVIE™              4.6      PT
# 12250  THE LEGO® NINJAGO® MOVIE™              4.5      PT
# 12251  THE LEGO® NINJAGO® MOVIE™              5.0      PT
# 12252  THE LEGO® NINJAGO® MOVIE™              4.5      PT
# 12253  THE LEGO® NINJAGO® MOVIE™              4.8      PT
# 12254  THE LEGO® NINJAGO® MOVIE™              3.6      PT
# 12255  THE LEGO® NINJAGO® MOVIE™              4.5      PT
# 12256  THE LEGO® NINJAGO® MOVIE™              4.2      PT
# 12257  THE LEGO® NINJAGO® MOVIE™              4.1      PT
# 12258  THE LEGO® NINJAGO® MOVIE™              4.5      PT
# 12259  THE LEGO® NINJAGO® MOVIE™              5.0      PT
# 12260  THE LEGO® NINJAGO® MOVIE™              4.8      PT
#
# [12261 rows x 14 columns]

# %% [markdown]
# # Variables
#
# The other thing that happened in our block of code above was that we defined a **variable**.
#
# This happened in the first line of code:
# ```df = pd.read_csv('causes_of_death_cleaned.csv')```
#
# As we saw, we used the built in *read_csv* method from the *pandas* package which we imported under the *alias* *pd*.
#
# The output of this method was then assigned to the variable *df*. This is the standard syntax for declaring any variable. You do not have to specify variable types, as in many other programming languages. Simply:
#
# `variable_name = what_to_stor_in_the_variable`

# %% [markdown]
# # Built in Python Functions
#
# We also used two built in python functions:
#     * len() #Returns the lenght of an object
#     * print() #Prints stuff!
# In general, **python has reserved keywords** for built in functions like this.
# **Be sure to not name your variables any of these!**
#
# <img src="python_built_in_functions.png" width=600>

# %% [markdown]
# You can also check what type of object something is using the built in **type()** method. This can be useful when determining how to work with an object that you are unfamiliar with.

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Common DataFrame Methods
# As you can see, our variable **df** is a DataFrame object (which is part of the Pandas core package). Here's some other common methods you will want to become familiar with when working with Pandas dataframes:
# * df.head()
#     * Preview the first 5 rows of a dataframe. Pass a number for more/less rows
# * df.tail(10)
#     * Preview last 10 rows (default 5 if no number given)
# * df.info()
#     * Returns column names and details about each column
# * df.columns
#     * Return column names. Note that there is no parentheses for this. This is becuase this is an attribute as opposed to a method

# %%
#Practice using some of these methods
df.columns
# Out:
# Index(['ages', 'list_price', 'num_reviews', 'piece_count', 'play_star_rating',
#        'prod_desc', 'prod_id', 'prod_long_desc', 'review_difficulty',
#        'set_name', 'star_rating', 'theme_name', 'val_star_rating', 'country'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12261 entries, 0 to 12260
# Data columns (total 14 columns):
# ages                 12261 non-null object
# list_price           12261 non-null float64
# num_reviews          10641 non-null float64
# piece_count          12261 non-null float64
# play_star_rating     10486 non-null float64
# prod_desc            11884 non-null object
# prod_id              12261 non-null float64
# prod_long_desc       12261 non-null object
# review_difficulty    10206 non-null object
# set_name             12261 non-null object
# star_rating          10641 non-null float64
# theme_name           12258 non-null object
# val_star_rating      10466 non-null float64
# country              12261 non-null object
# dtypes: float64(7), object(7)
# memory usage: 1.3+ MB

# %%
#Use tab completion to investigate at least 3 other methods under the df object. 
#Pull up their docstrings and investigate what they do.
df.blocks
# Out:
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/pandas/core
#  12252     60.9878         29.0        544.0               4.6  70612.0
#  12253     48.7878         21.0        494.0               4.6  70611.0
#  12254     36.5878         10.0        312.0               3.5  70608.0
#  12255     36.5878          8.0        341.0               4.2  70610.0
#  12256     36.5878          6.0        341.0               4.4  70609.0
#  12257     24.3878          8.0        217.0               4.1  70629.0
#  12258     24.3878         18.0        233.0               4.6  70607.0
#  12259     12.1878          1.0         48.0               5.0  70628.0
#  12260     12.1878         11.0        109.0               4.5  70606.0
#
#         star_rating  val_star_rating
#  0              4.5              4.0
#  1              5.0              4.0
#  2              4.3              4.1
#  3              4.6              4.3
#  4              4.6              4.1
#  5              4.9              4.4
#  6              4.2              4.1
#  7              4.7              4.3
#  8              4.7              4.1
#  9              4.8              4.5
#  10             4.4              3.6
#  11             4.6              4.4
#  12             4.6              4.2
#  13             3.4              3.5
#  14             4.8              4.8
#  15             5.0              5.0
#  16             5.0              5.0
#  17             3.0              4.0
#  18             4.0              4.0
#  19             4.7              4.5
#  20             5.0              5.0
#  21             5.0              5.0
#  22             5.0              NaN
#  23             4.5              4.0
#  24             4.9              4.7
#  25             5.0              5.0
#  26             4.0              3.0
#  27             5.0              4.8
#  28             5.0              4.5
#  29             4.0              3.0
#  ...            ...              ...
#  12231          3.2              3.4
#  12232          4.8              4.6
#  12233          4.8              4.4
#  12234          4.2              4.4
#  12235          4.5              4.0
#  12236          4.4              4.1
#  12237          4.6              4.4
#  12238          4.1              4.4
#  12239          4.7              4.6
#  12240          4.8              4.0
#  12241          4.8              3.5
#  12242          4.9              4.8
#  12243          4.9              4.8
#  12244          4.8              4.8
#  12245          4.9              4.8
#  12246          4.5              4.4
#  12247          4.8              4.7
#  12248          4.2              4.6
#  12249          5.0              4.6
#  12250          4.5              4.5
#  12251          4.3              5.0
#  12252          4.7              4.5
#  12253          4.5              4.8
#  12254          4.0              3.6
#  12255          4.6              4.5
#  12256          4.3              4.2
#  12257          3.6              4.1
#  12258          4.6              4.5
#  12259          5.0              5.0
#  12260          4.7              4.8
#
#  [12261 rows x 7 columns],
#  'object':        ages                                          prod_desc  \
#  0      6-12  Catapult into action and take back the eggs fr...
#  1      6-12  Launch a flying attack and rescue the eggs fro...
#  2      6-12  Chase the piggy with lightning-fast Chuck and ...
#  3       12+  Explore the architecture of the United States ...
#  4       12+  Recreate the Solomon R. Guggenheim Museum® wit...
#  5       12+  Celebrate Shanghai with this LEGO® Architectur...
#  6       12+  Celebrate New York City with this LEGO® Archit...
#  7       12+  Recreate Buckingham Palace with LEGO® Architec...
#  8       12+  Celebrate London with this LEGO® Architecture ...
#  9       12+  Celebrate Chicago with this LEGO® Architecture...
#  10      12+    Experience the grandeur of the Arc de Triomphe!
#  11      12+  Build your own LEGO® interpretation of the ico...
#  12      12+  Celebrate Sydney with this LEGO® Architecture ...
#  13     7-12                Bring your LEGO® creations to life!
#  14      10+      Build a LEGO® BrickHeadz version of yourself!
#  15      10+  Train a raptor with LEGO® BrickHeadz™ Owen and...
#  16      10+  Join Mr. Incredible and Frozone for LEGO® Bric...
#  12253                           Water Strider  THE LEGO® NINJAGO® MOVIE™
#  12254                            Master Falls  THE LEGO® NINJAGO® MOVIE™
#  12255                        Flying Jelly Sub  THE LEGO® NINJAGO® MOVIE™
#  12256                        Manta Ray Bomber  THE LEGO® NINJAGO® MOVIE™
#  12257                          Piranha Attack  THE LEGO® NINJAGO® MOVIE™
#  12258                     NINJAGO® City Chase  THE LEGO® NINJAGO® MOVIE™
#  12259                Lloyd - Spinjitzu Master  THE LEGO® NINJAGO® MOVIE™
#  12260                      Spinjitzu Training  THE LEGO® NINJAGO® MOVIE™
#
#        country
#  0          US
#  1          US
#  2          US
#  3          US
#  4          US
#  5          US
#  6          US
#  7          US
#  8          US
#  9          US
#  10         US
#  11         US
#  12         US
#  13         US
#  14         US
#  15         US
#  16         US
#  17         US
#  18         US
#  19         US
#  20         US
#  21         US
#  22         US
#  23         US
#  24         US
#  25         US
#  26         US
#  27         US
#  28         US
#  29         US
#  ...       ...
#  12231      PT
#  12232      PT
#  12233      PT
#  12234      PT
#  12235      PT
#  12236      PT
#  12237      PT
#  12238      PT
#  12239      PT
#  12240      PT
#  12241      PT
#  12242      PT
#  12243      PT
#  12244      PT
#  12245      PT
#  12246      PT
#  12247      PT
#  12248      PT
#  12249      PT
#  12250      PT
#  12251      PT
#  12252      PT
#  12253      PT
#  12254      PT
#  12255      PT
#  12256      PT
#  12257      PT
#  12258      PT
#  12259      PT
#  12260      PT
#
#  [12261 rows x 7 columns]}

# %%
df.as_matrix()
# Out:
# /anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Method .as_matrix will be removed in a future version. Use .values instead.
#   """Entry point for launching an IPython kernel.
# array([['6-12', 29.99, 2.0, ..., 'Angry Birds™', 4.0, 'US'],
#        ['6-12', 19.99, 2.0, ..., 'Angry Birds™', 4.0, 'US'],
#        ['6-12', 12.99, 11.0, ..., 'Angry Birds™', 4.1, 'US'],
#        ...,
#        ['7-14', 24.3878, 18.0, ..., 'THE LEGO® NINJAGO® MOVIE™', 4.5,
#         'PT'],
#        ['6-14', 12.1878, 1.0, ..., 'THE LEGO® NINJAGO® MOVIE™', 5.0,
#         'PT'],
#        ['6-14', 12.1878, 11.0, ..., 'THE LEGO® NINJAGO® MOVIE™', 4.8,
#         'PT']], dtype=object)

# %%
df.boxplot()

# %% [markdown]
# # Pandas Series
#
# While the entire spreadsheet is called a **dataframe**, each individual column is known as a **series**. You can access a specific column of a pandas dataframe one of two ways:
#
# `df['col_name']`
#
# or
#
# ```df.col_name```
#
# First note that in `df['col_name']` we need 'quotations' around the column name. The quotations denote the column name is a **string**, python's built in variable type for storing text. This can alternatively be replaced with double quotes `df["col_name"]`. In general, anything in quotations is a string in python code. Occassionally, with very ill formatted column names with quotations in the names themselves, you may even need to wrap a name in triple quotes `df["""col_name"""]` . This will rarely happen in this particular context, but is also the general pattern for dealing with messy strings.
#
# Note that the second method, `df.col_name`, will only work if there are no spaces within the name of the column. Similarly to tab completion with the command line, this is a primary reason why programers use dashes (-) and underscores (_) in lieu of whitespace in their variable and file names. Also note that no quotations are used when using this format. (The column names have been stored as attributes to the DataFrame object!)

# %%
#Previewing Data
df.head()
# Out:
#    ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0  6-12       29.99          2.0        277.0               4.0
# 1  6-12       19.99          2.0        168.0               4.0
# 2  6-12       12.99         11.0         74.0               4.3
# 3   12+       99.99         23.0       1032.0               3.6
# 4   12+       79.99         14.0        744.0               3.2
#
#                                            prod_desc  prod_id  \
# 0  Catapult into action and take back the eggs fr...  75823.0
# 1  Launch a flying attack and rescue the eggs fro...  75822.0
# 2  Chase the piggy with lightning-fast Chuck and ...  75821.0
# 3  Explore the architecture of the United States ...  21030.0
# 4  Recreate the Solomon R. Guggenheim Museum® wit...  21035.0
#
#                                       prod_long_desc review_difficulty  \
# 0  Use the staircase catapult to launch Red into ...           Average
# 1  Pilot Pig has taken off from Bird Island with ...              Easy
# 2  Pitch speedy bird Chuck against the Piggy Car....              Easy
# 3  Discover the architectural secrets of the icon...           Average
# 4  Discover the architectural secrets of Frank Ll...       Challenging
#
#                          set_name  star_rating    theme_name  val_star_rating  \
# 0           Bird Island Egg Heist          4.5  Angry Birds™              4.0
# 1              Piggy Plane Attack          5.0  Angry Birds™              4.0
# 2                Piggy Car Escape          4.3  Angry Birds™              4.1
# 3  United States Capitol Building          4.6  Architecture              4.3
# 4   Solomon R. Guggenheim Museum®          4.6  Architecture              4.1
#
#   country
# 0      US
# 1      US
# 2      US
# 3      US
# 4      US

# %%
df.head(2) #preview your spreadsheet again; 2 keeps it a nice small preview
# Out:
#    ages  list_price  num_reviews  piece_count  play_star_rating  \
# 0  6-12       29.99          2.0        277.0               4.0
# 1  6-12       19.99          2.0        168.0               4.0
#
#                                            prod_desc  prod_id  \
# 0  Catapult into action and take back the eggs fr...  75823.0
# 1  Launch a flying attack and rescue the eggs fro...  75822.0
#
#                                       prod_long_desc review_difficulty  \
# 0  Use the staircase catapult to launch Red into ...           Average
# 1  Pilot Pig has taken off from Bird Island with ...              Easy
#
#                 set_name  star_rating    theme_name  val_star_rating country
# 0  Bird Island Egg Heist          4.5  Angry Birds™              4.0      US
# 1     Piggy Plane Attack          5.0  Angry Birds™              4.0      US

# %%
df.ages.head()
# Out:
# 0    6-12
# 1    6-12
# 2    6-12
# 3     12+
# 4     12+
# Name: ages, dtype: object

# %%
df.ages[:5] #Here we introduce another new syntax the list slice [:5] this limits us to the first 5 items
# Out:
# 0    6-12
# 1    6-12
# 2    6-12
# 3     12+
# 4     12+
# Name: ages, dtype: object

# %% [markdown]
# # List and Series Slices
# Above, we introduced an entirely new programming pattern called a slice.
# The syntax for a slice is `[start:end]`.
#
# You can also pass an additional third parameter `[start:end:count_by]` which will allow you to:
# count every other: `[start:end:2]`
# count backwards: `start:end:-1]`
# or potentially much more cryptic patterns, depending on what you pass.
#
# While we could have also used `df.State.head()`, slicing works for many more datatypes. This includes the previously mentioned *strings* as well as **lists** and other iterable objects. **Series**, the columns of the pandas DataFrame are similar to python's built in *lists*, but also have additional *methods* built in to them that we will continue to investigate.

# %%
df.piece_count.head()
# Out:
# 0     277.0
# 1     168.0
# 2      74.0
# 3    1032.0
# 4     744.0
# Name: piece_count, dtype: float64

# %% [markdown]
# # Common Series Methods
# Some very useful series methods include:
# * df.col_name.value_counts()
# * df.col_name.astype()
# * series.mean()     #Changing notation here: series refers to df.col_name (which is a series)!
# * series.median()
# * series.min()
# * series.max()
# * series.std()
# * series.unique()
# * series.nunique()
# * series.sample()
# * series.sort_values()
#
# There are also many more but this is a very good starting point.
# Start pulling up some docstrings and getting acquainted with reading them yourself before we go through a few of these methods together.

# %%
df.play_star_rating.value_counts().head()#Read the docstring and tinker! See how it works.
# Out:
# 5.0    2219
# 4.5    1136
# 4.7     840
# 4.0     816
# 4.3     793
# Name: play_star_rating, dtype: int64

# %%
#Keep tinkering!
df.play_star_rating.head()
# Out:
# 0    4.0
# 1    4.0
# 2    4.3
# 3    3.6
# 4    3.2
# Name: play_star_rating, dtype: float64

# %%
df.play_star_rating.head().value_counts()
# Out:
# 4.0    2
# 3.2    1
# 3.6    1
# 4.3    1
# Name: play_star_rating, dtype: int64

# %%
df.index
# Out:
# RangeIndex(start=0, stop=12261, step=1)

# %%
df.columns
# Out:
# Index(['ages', 'list_price', 'num_reviews', 'piece_count', 'play_star_rating',
#        'prod_desc', 'prod_id', 'prod_long_desc', 'review_difficulty',
#        'set_name', 'star_rating', 'theme_name', 'val_star_rating', 'country'],
#       dtype='object')

# %% [markdown]
# # Practice questions
#
# It's time to put a little bit of this into practice.

# %% [markdown]
# ## 1. What are the 5 most common theme names?

# %%
#Your code/answer here
df.theme_name.value_counts().head()
# Out:
# Star Wars™                   1377
# DUPLO®                       1166
# City                         1092
# Juniors                       978
# THE LEGO® NINJAGO® MOVIE™     796
# Name: theme_name, dtype: int64

# %%
df.theme_name.value_counts()[:5]
# Out:
# Star Wars™                   1377
# DUPLO®                       1166
# City                         1092
# Juniors                       978
# THE LEGO® NINJAGO® MOVIE™     796
# Name: theme_name, dtype: int64

# %% [markdown]
# ## 2. What was the average lego set price?

# %%
#Your code/answer here
df.list_price.mean()
#df1 = pd.read_csv('lego_sets.csv')
# Out:
# 65.14199840959138

# %% [markdown]
# ## 3. Which set do you think is the most popular?

# %%
#Your code/answer here
df.theme_name.value_counts().head(1)
# Out:
# Star Wars™    1377
# Name: theme_name, dtype: int64

# %%
df.sort_values(by='star_rating', ascending=False)[['set_name','star_rating']]
# Out:
#                                         set_name  star_rating
# 5602                                   Star-Lord          5.0
# 2164                                    Pizzeria          5.0
# 2206            Azari & the Goblin Forest Escape          5.0
# 7335                           Creative Suitcase          5.0
# 4154                            Mia's Tree House          5.0
# 4150                          Snow Resort Chalet          5.0
# 9639                                     Cyborg™          5.0
# 2212                       Heartlake Riding Club          5.0
# 9637                               Wonder Woman™          5.0
# 9636                 Superman™ & Krypto™ Team-Up          5.0
# 2216                          Snow Resort Chalet          5.0
# 9633                   The Joker™ Batcave Attack          5.0
# 4146                       Heartlake Riding Club          5.0
# 2220                            Mia's Tree House          5.0
# 7346              LEGO® Large Creative Brick Box          5.0
# 2222                   Andrea's Park Performance          5.0
# 4140            Azari & the Goblin Forest Escape          5.0
# 2224              Andrea's Speedboat Transporter          5.0
# 9627                 Knightcrawler Tunnel Attack          5.0
# 9625                            The Joker™ Manor          5.0
# 2227                    Olivia's Mission Vehicle          5.0
# 7328                            Speed Record Car          5.0
# 4157              Andrea's Speedboat Transporter          5.0
# 2203    Breakout from the Goblin King's Fortress          5.0
# 2181                                   Preschool          5.0
# 4160                   Andrea's Park Performance          5.0
# 2170                            Rapunzel´s Tower          5.0
# 2171          LEGO® DUPLO® All-in-One-Box-of-Fun          5.0
# 2172                                  Fire Truck          5.0
# 9659                      Mini-Doll Dress-Up Kit          5.0
# ...                                          ...          ...
# 11992                  Mia's Organic Food Market          NaN
# 11995                      Mountain Police Chase          NaN
# 11998                  Zane's Ninja Boat Pursuit          NaN
# 12006                          Road Repair Truck          NaN
# 12010                           T. rex Transport          NaN
# 12013                            T. rex Breakout          NaN
# 12014                  Blue's Helicopter Pursuit          NaN
# 12016                        Raptor Rescue Truck          NaN
# 12017                               T. rex Tower          NaN
# 12019                          Pteranodon Escape          NaN
# 12040               Spider-Man & Hulk Adventures          NaN
# 12045        Mighty Micros: Star-Lord vs. Nebula          NaN
# 12046  Mighty Micros: Scarlet Spider vs. Sandman          NaN
# 12049                            EV3 Gyro Sensor          NaN
# 12052                        EV3 Infrared Sensor          NaN
# 12057                           EV3 Touch Sensor          NaN
# 12058                             EV3 Cable Pack          NaN
# 12065                            The Polar Igloo          NaN
# 12071                           The Nether Fight          NaN
# 12078                              Aaron's X-bow          NaN
# 12080                           Berserker Bomber          NaN
# 12082                      Lance's Hover Jouster          NaN
# 12096                        S.O.G. Headquarters          NaN
# 12106                  Zane's Ninja Boat Pursuit          NaN
# 12108                     Kai - Spinjitzu Master          NaN
# 12111                    Zane - Spinjitzu Master          NaN
# 12113                     Nya - Spinjitzu Master          NaN
# 12136                                Darth Maul™          NaN
# 12137                                  Han Solo™          NaN
# 12196                        Y-Wing Starfighter™          NaN
#
# [12261 rows x 2 columns]

# %%
df.sort_values(by='star_rating', ascending=False)
# Out:
#         ages  list_price  num_reviews  piece_count  play_star_rating  \
# 5602     10+     12.1878          1.0        113.0               5.0
# 2164     2-5     36.5878          2.0         57.0               5.0
# 2206    7-12     24.3878          2.0        145.0               5.0
# 7335    4-99     25.1860          2.0        213.0               5.0
# 4154    6-12     38.3520          2.0        351.0               5.0
# 4150    7-12     57.5520          4.0        402.0               5.0
# 9639     10+     12.9870          2.0        108.0               3.5
# 2212    6-12     85.3878          5.0        575.0               5.0
# 9637     10+     12.9870          5.0        143.0               4.6
# 9636    6-12     38.9870          1.0        199.0               5.0
# 2216    7-12     54.8878          4.0        402.0               5.0
# 9633     4-7     45.3700          1.0        151.0               5.0
# 4146    6-12     81.5520          5.0        575.0               5.0
# 2220    6-12     42.6878          2.0        351.0               5.0
# 7346    4-99     55.9860          4.0        790.0               5.0
# 2222    6-12     36.5878          1.0        229.0               5.0
# 4140    7-12     28.7520          2.0        145.0               5.0
# 2224    6-12     36.5878          1.0        309.0               5.0
# 9627    7-14     77.8700          6.0        622.0               5.0
# 9625     14+    389.8700         19.0       3444.0               4.9
# 2227    6-12     24.3878          1.0        223.0               5.0
# 7328    5-12     11.1860          1.0         78.0               4.0
# 4157    6-12     38.3520          1.0        309.0               5.0
# 2203    8-12     97.5878          1.0        695.0               NaN
# 2181     2-5     24.3878          2.0         39.0               5.0
# 4160    6-12     33.5520          1.0        229.0               5.0
# 2170     2-5     36.5878          1.0         37.0               5.0
# 2171    1½-5     36.5878          4.0         65.0               4.8
# 2172     2-5     32.9278          2.0         26.0               5.0
# 9659      6+     15.5870          1.0         80.0               5.0
# ...      ...         ...          ...          ...               ...
# 11992    4-7     24.3878          NaN        115.0               NaN
# 11995    4-7     24.3878          NaN        115.0               NaN
# 11998    4-7     24.3878          NaN        131.0               NaN
# 12006    4-7     12.1878          NaN         73.0               NaN
# 12010   7-12     97.5878          NaN        609.0               NaN
# 12013    4-7     67.0878          NaN        150.0               NaN
# 12014   7-12     60.9878          NaN        397.0               NaN
# 12016    4-7     36.5878          NaN         85.0               NaN
# 12017    2-5     36.5878          NaN         22.0               NaN
# 12019    4-7     30.4878          NaN         84.0               NaN
# 12040    2-5     36.5878          NaN         38.0               NaN
# 12045   5-12     12.1878          NaN         86.0               NaN
# 12046   5-12     12.1878          NaN         89.0               NaN
# 12049  10-21     42.6878          NaN          1.0               NaN
# 12052  10-21     42.6878          NaN          1.0               NaN
# 12057  10-21     24.3878          NaN          1.0               NaN
# 12058  10-21     18.2878          NaN          7.0               NaN
# 12065     8+     54.8878          NaN        278.0               NaN
# 12071   6-14     18.2878          NaN         84.0               NaN
# 12078   8-14     69.5278          NaN        569.0               NaN
# 12080   8-14     36.5878          NaN        369.0               NaN
# 12082   7-14     24.3878          NaN        217.0               NaN
# 12096   8-14     54.8878          NaN        530.0               NaN
# 12106    4-7     24.3878          NaN        131.0               NaN
# 12108   6-14     12.1878          NaN         61.0               NaN
# 12111   6-14     12.1878          NaN         69.0               NaN
# 12113   6-14     12.1878          NaN         69.0               NaN
# 12136   8-14     36.5878          NaN        104.0               NaN
# 12137   8-14     36.5878          NaN        101.0               NaN
# 12196    14+    243.9878          NaN       1967.0               NaN
#
#                                                prod_desc  prod_id  \
# 5602   Be a legendary outlaw with LEGO® BrickHeadz St...  41606.0
# 2164   Enjoy a delicious pizza at the LEGO® DUPLO® Pi...  10834.0
# 2206   Escape the carnivorous plants with Azari and F...  41186.0
# 7335   Bring along a world of creativity in your own ...  10713.0
# 4154   Climb up to the tree house and help Mia settle...  41335.0
# 4150      Stay cozy and warm in the beautiful log cabin!  41323.0
# 9639        Get an upgrade with LEGO® BrickHeadz Cyborg™  41601.0
# 2212   Train for the next big horse show at the Heart...  41126.0
# 9637     Stand tall with LEGO® BrickHeadz Wonder Woman™!  41599.0
# 9636   Help Superman™ bust out of the Kryptonite prison!  76096.0
# 2216      Stay cozy and warm in the beautiful log cabin!  41323.0
# 9633       Swoop in with Batman™ and take on the Joker™!  10753.0
# 4146   Train for the next big horse show at the Heart...  41126.0
# 2220   Climb up to the tree house and help Mia settle...  41335.0
# 7346   Create all kinds of buildings with LEGO® brick...  10698.0
# 2222   Put on a show in the park with Andrea and Pepper!  41334.0
# 12137  Play out exciting adventures with this highly ...               NaN
# 12196  Own part of Star Wars history with the Y-Wing ...               NaN
#
#                                         set_name  star_rating  \
# 5602                                   Star-Lord          5.0
# 2164                                    Pizzeria          5.0
# 2206            Azari & the Goblin Forest Escape          5.0
# 7335                           Creative Suitcase          5.0
# 4154                            Mia's Tree House          5.0
# 4150                          Snow Resort Chalet          5.0
# 9639                                     Cyborg™          5.0
# 2212                       Heartlake Riding Club          5.0
# 9637                               Wonder Woman™          5.0
# 9636                 Superman™ & Krypto™ Team-Up          5.0
# 2216                          Snow Resort Chalet          5.0
# 9633                   The Joker™ Batcave Attack          5.0
# 4146                       Heartlake Riding Club          5.0
# 2220                            Mia's Tree House          5.0
# 7346              LEGO® Large Creative Brick Box          5.0
# 2222                   Andrea's Park Performance          5.0
# 4140            Azari & the Goblin Forest Escape          5.0
# 2224              Andrea's Speedboat Transporter          5.0
# 9627                 Knightcrawler Tunnel Attack          5.0
# 9625                            The Joker™ Manor          5.0
# 2227                    Olivia's Mission Vehicle          5.0
# 7328                            Speed Record Car          5.0
# 4157              Andrea's Speedboat Transporter          5.0
# 2203    Breakout from the Goblin King's Fortress          5.0
# 2181                                   Preschool          5.0
# 4160                   Andrea's Park Performance          5.0
# 2170                            Rapunzel´s Tower          5.0
# 2171          LEGO® DUPLO® All-in-One-Box-of-Fun          5.0
# 2172                                  Fire Truck          5.0
# 9659                      Mini-Doll Dress-Up Kit          5.0
# ...                                          ...          ...
# 11992                  Mia's Organic Food Market          NaN
# 11995                      Mountain Police Chase          NaN
# 11998                  Zane's Ninja Boat Pursuit          NaN
# 12006                          Road Repair Truck          NaN
# 12010                           T. rex Transport          NaN
# 12013                            T. rex Breakout          NaN
# 12014                  Blue's Helicopter Pursuit          NaN
# 12016                        Raptor Rescue Truck          NaN
# 12017                               T. rex Tower          NaN
# 12019                          Pteranodon Escape          NaN
# 12040               Spider-Man & Hulk Adventures          NaN
# 12045        Mighty Micros: Star-Lord vs. Nebula          NaN
# 12046  Mighty Micros: Scarlet Spider vs. Sandman          NaN
# 12049                            EV3 Gyro Sensor          NaN
# 12052                        EV3 Infrared Sensor          NaN
# 12057                           EV3 Touch Sensor          NaN
# 12058                             EV3 Cable Pack          NaN
# 12065                            The Polar Igloo          NaN
# 12071                           The Nether Fight          NaN
# 12078                              Aaron's X-bow          NaN
# 12080                           Berserker Bomber          NaN
# 12082                      Lance's Hover Jouster          NaN
# 12096                        S.O.G. Headquarters          NaN
# 12106                  Zane's Ninja Boat Pursuit          NaN
# 12108                     Kai - Spinjitzu Master          NaN
# 12111                    Zane - Spinjitzu Master          NaN
# 12113                     Nya - Spinjitzu Master          NaN
# 12136                                Darth Maul™          NaN
# 12137                                  Han Solo™          NaN
# 12196                        Y-Wing Starfighter™          NaN
#
#                       theme_name  val_star_rating country
# 5602                  BrickHeadz              5.0      ES
# 2164                      DUPLO®              5.0      BE
# 2206                       Elves              3.5      BE
# 7335                     Classic              5.0      GB
# 4154                     Friends              5.0      CZ
# 4150                     Friends              4.5      CZ
# 9639                  BrickHeadz              4.0      NO
# 2212                     Friends              5.0      BE
# 9637                  BrickHeadz              5.0      NO
# 9636     DC Comics™ Super Heroes              5.0      NO
# 2216                     Friends              4.5      BE
# 9633                     Juniors              5.0      NO
# 4146                     Friends              5.0      CZ
# 2220                     Friends              5.0      BE
# 7346                     Classic              5.0      GB
# 2222                     Friends              5.0      BE
# 4140                       Elves              3.5      CZ
# 2224                     Friends              5.0      BE
# 9627     DC Comics™ Super Heroes              4.8      NO
# 9625      THE LEGO® BATMAN MOVIE              4.9      NO
# 2227                     Friends              5.0      BE
# 7328                        City              4.0      GB
# 4157                     Friends              5.0      CZ
# 2203                       Elves              NaN      BE
# 2181                      DUPLO®              5.0      BE
# 4160                     Friends              5.0      CZ
# 2170                      DUPLO®              5.0      BE
# 2171                      DUPLO®              4.0      BE
# 2172                      DUPLO®              5.0      BE
# 9659                     Disney™              5.0      NO
# ...                          ...              ...     ...
# 11992                    Juniors              NaN      PT
# 11995                    Juniors              NaN      PT
# 11998                    Juniors              NaN      PT
# 12006                    Juniors              NaN      PT
# 12010           T. rex Transport              NaN      PT
# 12013                    Juniors              NaN      PT
# 12014  Blue's Helicopter Pursuit              NaN      PT
# 12016                    Juniors              NaN      PT
# 12017                     DUPLO®              NaN      PT
# 12019                    Juniors              NaN      PT
# 12040                     DUPLO®              NaN      PT
# 12045        Marvel Super Heroes              NaN      PT
# 12046        Marvel Super Heroes              NaN      PT
# 12049                MINDSTORMS®              NaN      PT
# 12052                MINDSTORMS®              NaN      PT
# 12057                MINDSTORMS®              NaN      PT
# 12058                MINDSTORMS®              NaN      PT
# 12065                 Minecraft™              NaN      PT
# 12071                 Minecraft™              NaN      PT
# 12078              NEXO KNIGHTS™              NaN      PT
# 12080              NEXO KNIGHTS™              NaN      PT
# 12082              NEXO KNIGHTS™              NaN      PT
# 12096                   NINJAGO®              NaN      PT
# 12106                    Juniors              NaN      PT
# 12108                   NINJAGO®              NaN      PT
# 12111                   NINJAGO®              NaN      PT
# 12113                   NINJAGO®              NaN      PT
# 12136                 Star Wars™              NaN      PT
# 12137                 Star Wars™              NaN      PT
# 12196                 Star Wars™              NaN      PT
#
# [12261 rows x 14 columns]

# %%
df.set_name.value_counts()
# Out:
# Chewbacca™                                63
# Kylo Ren™                                 63
# Rey                                       63
# Han Solo™                                 62
# Iron Man MK50                             42
# Star-Lord                                 42
# Owen & Blue                               42
# Cruz Ramirez Race Simulator               42
# Quake Mech                                42
# Y-Wing Starfighter™                       42
# Destiny's Bounty                          42
# Garmadon's Volcano Lair                   42
# Aquaman™                                  42
# Lloyd - Spinjitzu Master                  42
# Lightning McQueen Speed Launcher          42
# THE LEGO® BATMAN MOVIE Series 2           42
# Temple of The Ultimate Ultimate Weapon    42
# Raptor Rescue Truck                       42
# Gentle Giants Petting Zoo                 42
# Water Strider                             42
# Anna & Elsa's Frozen Playground           42
# Piranha Attack                            42
# The Joker™ Batcave Attack                 42
# NINJAGO® City                             42
# Lightning Jet                             42
# The Bat-Dune Buggy                        42
# Thanos                                    42
# Willy's Butte Speed Training              42
# Green Ninja Mech Dragon                   42
# The Flash™                                42
#                                           ..
# Anna & Kristoff’s Sleigh Adventure         2
# Iron Man vs. Ultron                        2
# Moltor’s Lava Smasher                      2
# Encounter on Jakku™                        2
# Rey's Speeder™                             2
# My First Bird                              2
# Police Truck Chase                         2
# Police Helicopter Chase                    2
# Bird Island Egg Heist                      2
# Piggy Plane Attack                         2
# Ultimate Axl                               2
# Mine Loader                                2
# Record Breaker                             2
# Midway Arcade™ Level Pack                  2
# Tanker Truck Takedown                      2
# Mighty Micros: Spider-Man vs. Scorpion     2
# TIE Advanced Prototype™                    2
# Series 17                                  2
# My First Cakes                             2
# LEGO® Power Functions Motor Set            2
# Kryptonite Interception                    2
# StarScavenger™                             2
# LEGO® Creative Supplement Bright           2
# LEGO® DIMENSIONS™ Gollum Fun Pack          2
# Airport Starter Set                        2
# The Vermillion Attack                      2
# LEGO® Friends Advent Calendar              2
# Airport Cargo Plane                        2
# My First Vehicles                          1
# Moana's Ocean Voyage                       1
# Name: set_name, Length: 741, dtype: int64

# %% [markdown]
# # Graphing
#
# Our bread and butter tool for graphing in python will be **matplotlib**.
# There are a number of other packages you can also check out for visualization later on such as plotly, folium, and bokeh to name a few, but matplotlib is an industry standard used widely. As with the pandas package, we must import  the matplotlib package to use its built in functions and methods. Rather then import the entire package however, we import only the piece we intend to use (hence the dot notation) and again alias this under the shorthand *plt*. Finally, the iPython magic command **% matplotlib inline** makes these graphs appear within our jupyter notebook.

# %%
#import a subset of the matplotlib package under the alias 'plt'
import matplotlib.pyplot as plt

#ipython magic command for displaying graphs within the notebook
# %matplotlib inline

# %%
to_graph = df.theme_name.value_counts()[:5]
to_graph.plot(kind='barh')

# %% [markdown]
# # Adding labels
# The graph above is a good start, but we should be sure to add some labels! To do this we make successive calls to the `plt` package we imported. Some common methods you should be familiar with include:
# * plt.title()
# * plt.xlabel()
# * plt.ylabel()
# * plt.legend()
# * plt.xticks()
# * plt.yticks()

# %%
to_graph = df.theme_name.value_counts()[:5]
to_graph.plot(kind='barh') #lots of other optional parameters can be passed such as color
plt.title('Top 5 Lego Themes', fontsize=16) #fontsize is optional
plt.xlabel('Number of Lego Sets') #you could also pass in fontsize if you wanted here
plt.ylabel('Theme') #you could also rotate text if you wanted
# Out:
# Text(0, 0.5, 'Theme')

# %% [markdown]
# # Practice and Explore
#
# Take a minute to try chaining some of these methods together to create a few of your own visuals for practice. Some ideas can include making a scatter plot with `plt.scatter(x , y)` where you pass in two series (one as x and the other as y), plotting histograms with the `series.hist()` method, or creating simple bar graphs as shown above.

# %%
plt.scatter(df.play_star_rating, df.star_rating)

# %%
df.play_star_rating.hist()

# %%
#Your code here
df.star_rating.hist()

# %%
to_graph = df.play_star_rating.value_counts()[:5]
to_graph.plot(kind='barh') #lots of other optional parameters can be passed such as color
plt.title('Top 5 Lego Themes', fontsize=16) #fontsize is optional
plt.xlabel('Number of Lego Sets') #you could also pass in fontsize if you wanted here
plt.ylabel('Theme') #you could also rotate text if you wanted
# Out:
# Text(0, 0.5, 'Theme')
